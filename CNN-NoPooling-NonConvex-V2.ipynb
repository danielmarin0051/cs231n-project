# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

FOLDERNAME = 'cs231n-project/daniel/'

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/cs231n-project/daniel

# %%
import numpy as np 
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from torchvision import datasets
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
import tqdm.notebook as tq
from time import time

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 6) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.style.use('seaborn')

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
dtype = torch.float
print(f'device: {device}')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# device: cpu

# %%
C = 2
BATCH_SIZE = 100
# NUM_TRAIN = 1250
# Only during dev:
NUM_TRAIN = 1000

def load_Fashion_MNIST():
  transform = T.Compose([T.ToTensor(), T.Normalize(mean=0.3139, std=0.3626)])
  train_dset = datasets.FashionMNIST('./datasets', train=True, download=True, transform=transform)
  test_dset = datasets.FashionMNIST('./datasets', train=False, download=True, transform=transform)
  
  # Get only first two classes
  train_dset.data = train_dset.data[train_dset.targets < C]
  train_dset.targets = train_dset.targets[train_dset.targets < C]
  test_dset.data = test_dset.data[test_dset.targets < C]
  test_dset.targets = test_dset.targets[test_dset.targets < C]

  ## Only on dev
  train_dset.data = train_dset.data[:NUM_TRAIN]
  train_dset.targets = train_dset.targets[:NUM_TRAIN]

  return train_dset, test_dset

train_dset, test_dset = load_Fashion_MNIST()
print(train_dset.data.shape, train_dset.targets.shape)
print(test_dset.data.shape, test_dset.targets.shape)

def get_loaders():
  train_loader = DataLoader(train_dset, batch_size=BATCH_SIZE, shuffle=False)
  test_loader = DataLoader(test_dset, batch_size=BATCH_SIZE, shuffle=False)
  return train_loader, test_loader

train_loader, test_loader = get_loaders()
# Out:
# torch.Size([1000, 28, 28]) torch.Size([1000])
# torch.Size([2000, 28, 28]) torch.Size([2000])

# %%
def check_accuracy(loader, model, loss_fn):  
    num_correct, num_samples = 0, 0
    model.eval()
    loss = 0.0
    with torch.no_grad():
        for X, y in loader:
            X = X.to(device=device, dtype=dtype)
            y = y.to(device=device, dtype=torch.long)
            scores = model(X).squeeze()
            loss += loss_fn(scores, y, model, scale_for_SGD=False)
            preds = (scores > 0.5).long()
            num_correct += (preds == y).sum()
            num_samples += preds.shape[0]
    acc = float(num_correct) / num_samples
    return acc, loss, num_correct, num_samples

def print_stats(iteration, loss, accuracy, num_correct, num_samples, dset):
  print('It: %d, %s | loss: %.3f, acc: %.2f%%, ratio: %d/%d' % (iteration, dset,  loss, 100 * accuracy, num_correct, num_samples))

def train(model, loss_fn, optimizer, train_loader, epochs, check_every, acc_check_loader_train, acc_check_loader_test, verbose):
  train_loss_history = []
  train_accuracy_history = []
  test_loss_history = []
  test_accuracy_history = []
  times = []
  start = time()
  done = False
  for e in tq.tqdm(range(epochs)):
    if done:
      break
    if verbose: 
      print(f'### Epoch {e} ###')
    for t, (X, y) in enumerate(train_loader):
      model.train()
      scores = model(X)

      # Forward pass
      loss = loss_fn(scores, y, model, scale_for_SGD=True)
      
      # Backward pass
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      if check_every is not None and (e*epochs + t) % check_every == 0:
        train_accuracy, train_loss, train_num_correct, train_num_samples = check_accuracy(acc_check_loader_train, model, loss_fn)
        test_accuracy, test_loss, test_num_correct, test_num_samples = check_accuracy(acc_check_loader_test, model, loss_fn)
        times.append(time() - start)
        train_loss_history.append(train_loss)
        train_accuracy_history.append(train_accuracy)
        test_loss_history.append(test_loss)
        test_accuracy_history.append(test_accuracy)
        if verbose:
          print_stats((e*epochs + t), train_loss, train_accuracy, train_num_correct, train_num_samples, 'train')
          print_stats((e*epochs + t), test_loss, test_accuracy, test_num_correct, test_num_samples, 'test')
        if train_accuracy == 1.0:
          done = True
          break
  
  return train_loss_history, train_accuracy_history, test_loss_history, test_accuracy_history, times

# %%
class Polly(nn.Module):
  def forward(self, x):
    return (0.09 * x**2 + 0.5 * x + 0.47)

class Conv2dUnitNorm(nn.Module):
  def __init__(self, in_channels, out_channels, kernel_size, stride, padding):
    super(Conv2dUnitNorm, self).__init__()
    self.Conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)

  def forward(self, x):
    W = self.Conv2d.weight                               # (C_out, 1, F, F)
    C_out = W.shape[0]
    norm = torch.linalg.norm(W.view((C_out, -1)), dim=1) # (C_out, )
    norm = norm.reshape((1, C_out, 1, 1)) # reshape for broadcast
    out = self.Conv2d(x) / norm           # (N, C_out, new_width, new_height)
    return out

H = 64
beta = 10**(-6)

model = nn.Sequential(
  Conv2dUnitNorm(in_channels=1, out_channels=H, kernel_size=4, stride=4, padding=0),
  Polly(),
  nn.Flatten(),
  nn.Linear(H * 7 * 7, 1, bias=False)
)

def loss_fn(scores, y, model, scale_for_SGD):
  N = scores.shape[0]
  W2 = model[3].weight
  if scale_for_SGD:
    loss = 0.5*((scores.squeeze() - y)**2).sum() * NUM_TRAIN/N + beta * torch.abs(W2).sum()
  else:
    loss = 0.5*((scores.squeeze() - y)**2).sum() + beta * torch.abs(W2).sum() * N/NUM_TRAIN
  return loss


optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# optimizer = torch.optim.SGD(model.parameters(), lr=10**(-9), momentum=0.9)
train_loss_history, train_accuracy_history, test_loss_history, test_accuracy_history, times = train(
    model, loss_fn, optimizer, train_loader, epochs=150,
    check_every=10, acc_check_loader_train=train_loader, acc_check_loader_test=test_loader, verbose=True,
)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# ### Epoch 0 ###
# It: 0, train | loss: 300.190, acc: 40.10%, ratio: 401/1000
# It: 0, test | loss: 558.562, acc: 44.65%, ratio: 893/2000
# ### Epoch 1 ###
# It: 150, train | loss: 109.887, acc: 64.40%, ratio: 644/1000
# It: 150, test | loss: 230.222, acc: 62.65%, ratio: 1253/2000
# ### Epoch 2 ###
# It: 300, train | loss: 47.193, acc: 92.90%, ratio: 929/1000
# It: 300, test | loss: 92.120, acc: 93.70%, ratio: 1874/2000
# ### Epoch 3 ###
# It: 450, train | loss: 35.954, acc: 92.00%, ratio: 920/1000
# It: 450, test | loss: 73.720, acc: 92.05%, ratio: 1841/2000
# ### Epoch 4 ###
# It: 600, train | loss: 32.921, acc: 95.40%, ratio: 954/1000
# It: 600, test | loss: 67.189, acc: 95.65%, ratio: 1913/2000
# ### Epoch 5 ###
# It: 750, train | loss: 29.510, acc: 95.30%, ratio: 953/1000
# It: 750, test | loss: 60.143, acc: 95.90%, ratio: 1918/2000
# ### Epoch 6 ###
# It: 900, train | loss: 27.409, acc: 96.10%, ratio: 961/1000
# It: 900, test | loss: 55.891, acc: 96.40%, ratio: 1928/2000
# ### Epoch 7 ###
# It: 1050, train | loss: 26.420, acc: 96.50%, ratio: 965/1000
# It: 1050, test | loss: 54.032, acc: 96.70%, ratio: 1934/2000
# ### Epoch 8 ###
# It: 1200, train | loss: 25.466, acc: 96.80%, ratio: 968/1000
# It: 1200, test | loss: 52.279, acc: 96.90%, ratio: 1938/2000
# ### Epoch 9 ###
# It: 1350, train | loss: 24.544, acc: 97.00%, ratio: 970/1000
# It: 1350, test | loss: 50.465, acc: 97.10%, ratio: 1942/2000
# ### Epoch 10 ###
# It: 1500, train | loss: 23.787, acc: 97.20%, ratio: 972/1000
# It: 1500, test | loss: 49.081, acc: 97.30%, ratio: 1946/2000
# ### Epoch 11 ###
# It: 1650, train | loss: 23.053, acc: 97.30%, ratio: 973/1000
# It: 1650, test | loss: 47.713, acc: 97.45%, ratio: 1949/2000
# ### Epoch 12 ###
# It: 1800, train | loss: 22.360, acc: 97.50%, ratio: 975/1000
# It: 1800, test | loss: 46.415, acc: 97.65%, ratio: 1953/2000
# ### Epoch 13 ###
# It: 1950, train | loss: 21.715, acc: 97.90%, ratio: 979/1000
# It: 1950, test | loss: 45.229, acc: 97.75%, ratio: 1955/2000
# ### Epoch 14 ###
# It: 2100, train | loss: 21.103, acc: 97.90%, ratio: 979/1000
# It: 2100, test | loss: 44.101, acc: 97.95%, ratio: 1959/2000
# ### Epoch 15 ###
# It: 2250, train | loss: 20.522, acc: 97.90%, ratio: 979/1000
# It: 2250, test | loss: 43.037, acc: 97.95%, ratio: 1959/2000
# ### Epoch 16 ###
# It: 2400, train | loss: 19.975, acc: 98.00%, ratio: 980/1000
# It: 2400, test | loss: 42.047, acc: 98.05%, ratio: 1961/2000
# ### Epoch 17 ###
# It: 2550, train | loss: 19.459, acc: 98.00%, ratio: 980/1000
# It: 2550, test | loss: 41.121, acc: 98.15%, ratio: 1963/2000
# ### Epoch 18 ###
# It: 2700, train | loss: 18.970, acc: 98.20%, ratio: 982/1000
# It: 2700, test | loss: 40.251, acc: 98.20%, ratio: 1964/2000
# ### Epoch 19 ###
# It: 2850, train | loss: 18.510, acc: 98.30%, ratio: 983/1000
# It: 2850, test | loss: 39.436, acc: 98.30%, ratio: 1966/2000
# ### Epoch 20 ###
# It: 3000, train | loss: 18.074, acc: 98.30%, ratio: 983/1000
# It: 3000, test | loss: 38.673, acc: 98.25%, ratio: 1965/2000
# ### Epoch 21 ###
# It: 3150, train | loss: 17.664, acc: 98.30%, ratio: 983/1000
# It: 3150, test | loss: 37.959, acc: 98.25%, ratio: 1965/2000
# ### Epoch 22 ###
# It: 3300, train | loss: 17.276, acc: 98.40%, ratio: 984/1000
# It: 3300, test | loss: 37.289, acc: 98.20%, ratio: 1964/2000
# ### Epoch 23 ###
# It: 3450, train | loss: 16.909, acc: 98.40%, ratio: 984/1000
# It: 3450, test | loss: 36.662, acc: 98.25%, ratio: 1965/2000
# ### Epoch 24 ###
# It: 3600, train | loss: 16.562, acc: 98.40%, ratio: 984/1000
# It: 3600, test | loss: 36.074, acc: 98.25%, ratio: 1965/2000
# ### Epoch 25 ###
# It: 3750, train | loss: 16.234, acc: 98.40%, ratio: 984/1000
# It: 3750, test | loss: 35.522, acc: 98.25%, ratio: 1965/2000
# ### Epoch 26 ###
# It: 3900, train | loss: 15.923, acc: 98.50%, ratio: 985/1000
# It: 3900, test | loss: 35.005, acc: 98.25%, ratio: 1965/2000
# ### Epoch 27 ###
# It: 4050, train | loss: 15.629, acc: 98.50%, ratio: 985/1000
# It: 4050, test | loss: 34.520, acc: 98.25%, ratio: 1965/2000
# ### Epoch 28 ###
# It: 4200, train | loss: 15.350, acc: 98.60%, ratio: 986/1000
# It: 4200, test | loss: 34.065, acc: 98.30%, ratio: 1966/2000
# ### Epoch 29 ###
# It: 4350, train | loss: 15.085, acc: 98.60%, ratio: 986/1000
# It: 4350, test | loss: 33.637, acc: 98.30%, ratio: 1966/2000
# ### Epoch 30 ###
# It: 4500, train | loss: 14.833, acc: 98.60%, ratio: 986/1000
# It: 4500, test | loss: 33.235, acc: 98.30%, ratio: 1966/2000
# ### Epoch 31 ###
# It: 4650, train | loss: 14.594, acc: 98.60%, ratio: 986/1000
# It: 4650, test | loss: 32.856, acc: 98.30%, ratio: 1966/2000
# ### Epoch 32 ###
# It: 4800, train | loss: 14.365, acc: 98.70%, ratio: 987/1000
# It: 4800, test | loss: 32.500, acc: 98.30%, ratio: 1966/2000
# ### Epoch 33 ###
# It: 4950, train | loss: 14.148, acc: 98.70%, ratio: 987/1000
# It: 4950, test | loss: 32.165, acc: 98.25%, ratio: 1965/2000
# ### Epoch 34 ###
# It: 5100, train | loss: 13.940, acc: 98.70%, ratio: 987/1000
# It: 5100, test | loss: 31.848, acc: 98.30%, ratio: 1966/2000
# ### Epoch 35 ###
# It: 5250, train | loss: 13.742, acc: 98.70%, ratio: 987/1000
# It: 5250, test | loss: 31.549, acc: 98.30%, ratio: 1966/2000
# ### Epoch 36 ###
# It: 5400, train | loss: 13.551, acc: 98.80%, ratio: 988/1000
# It: 5400, test | loss: 31.266, acc: 98.30%, ratio: 1966/2000
# ### Epoch 37 ###
# It: 5550, train | loss: 13.369, acc: 98.80%, ratio: 988/1000
# It: 5550, test | loss: 30.999, acc: 98.30%, ratio: 1966/2000
# ### Epoch 38 ###
# It: 5700, train | loss: 13.195, acc: 98.80%, ratio: 988/1000
# It: 5700, test | loss: 30.745, acc: 98.35%, ratio: 1967/2000
# ### Epoch 39 ###
# It: 5850, train | loss: 13.027, acc: 98.80%, ratio: 988/1000
# It: 5850, test | loss: 30.505, acc: 98.35%, ratio: 1967/2000
# ### Epoch 40 ###
# It: 6000, train | loss: 12.865, acc: 98.80%, ratio: 988/1000
# It: 6000, test | loss: 30.277, acc: 98.35%, ratio: 1967/2000
# ### Epoch 41 ###
# It: 6150, train | loss: 12.710, acc: 98.80%, ratio: 988/1000
# It: 6150, test | loss: 30.059, acc: 98.35%, ratio: 1967/2000
# ### Epoch 42 ###
# It: 6300, train | loss: 12.560, acc: 98.90%, ratio: 989/1000
# It: 6300, test | loss: 29.852, acc: 98.35%, ratio: 1967/2000
# ### Epoch 43 ###
# It: 6450, train | loss: 12.415, acc: 98.90%, ratio: 989/1000
# It: 6450, test | loss: 29.655, acc: 98.35%, ratio: 1967/2000
# ### Epoch 44 ###
# It: 6600, train | loss: 12.275, acc: 98.90%, ratio: 989/1000
# It: 6600, test | loss: 29.467, acc: 98.35%, ratio: 1967/2000
# ### Epoch 45 ###
# It: 6750, train | loss: 12.140, acc: 98.90%, ratio: 989/1000
# It: 6750, test | loss: 29.287, acc: 98.35%, ratio: 1967/2000
# ### Epoch 46 ###
# It: 6900, train | loss: 12.009, acc: 98.90%, ratio: 989/1000
# It: 6900, test | loss: 29.116, acc: 98.35%, ratio: 1967/2000
# ### Epoch 47 ###
# It: 7050, train | loss: 11.883, acc: 98.90%, ratio: 989/1000
# It: 7050, test | loss: 28.952, acc: 98.35%, ratio: 1967/2000
# ### Epoch 48 ###
# It: 7200, train | loss: 11.761, acc: 98.90%, ratio: 989/1000
# It: 7200, test | loss: 28.795, acc: 98.35%, ratio: 1967/2000
# ### Epoch 49 ###
# It: 7350, train | loss: 11.643, acc: 98.90%, ratio: 989/1000
# It: 7350, test | loss: 28.645, acc: 98.35%, ratio: 1967/2000
# ### Epoch 50 ###
# It: 7500, train | loss: 11.528, acc: 98.90%, ratio: 989/1000
# It: 7500, test | loss: 28.502, acc: 98.35%, ratio: 1967/2000
# ### Epoch 51 ###
# It: 7650, train | loss: 11.418, acc: 98.90%, ratio: 989/1000
# It: 7650, test | loss: 28.365, acc: 98.30%, ratio: 1966/2000
# ### Epoch 52 ###
# It: 7800, train | loss: 11.310, acc: 98.90%, ratio: 989/1000
# It: 7800, test | loss: 28.235, acc: 98.30%, ratio: 1966/2000
# ### Epoch 53 ###
# It: 7950, train | loss: 11.207, acc: 98.90%, ratio: 989/1000
# It: 7950, test | loss: 28.111, acc: 98.30%, ratio: 1966/2000
# ### Epoch 54 ###
# It: 8100, train | loss: 11.107, acc: 99.00%, ratio: 990/1000
# It: 8100, test | loss: 27.992, acc: 98.30%, ratio: 1966/2000
# ### Epoch 55 ###
# It: 8250, train | loss: 11.010, acc: 99.00%, ratio: 990/1000
# It: 8250, test | loss: 27.880, acc: 98.30%, ratio: 1966/2000
# ### Epoch 56 ###
# It: 8400, train | loss: 10.916, acc: 99.00%, ratio: 990/1000
# It: 8400, test | loss: 27.772, acc: 98.30%, ratio: 1966/2000
# ### Epoch 57 ###
# It: 8550, train | loss: 10.824, acc: 99.00%, ratio: 990/1000
# It: 8550, test | loss: 27.669, acc: 98.30%, ratio: 1966/2000
# ### Epoch 58 ###
# It: 8700, train | loss: 10.736, acc: 99.00%, ratio: 990/1000
# It: 8700, test | loss: 27.571, acc: 98.35%, ratio: 1967/2000
# ### Epoch 59 ###
# It: 8850, train | loss: 10.649, acc: 99.00%, ratio: 990/1000
# It: 8850, test | loss: 27.477, acc: 98.35%, ratio: 1967/2000
# ### Epoch 60 ###
# It: 9000, train | loss: 10.565, acc: 99.00%, ratio: 990/1000
# It: 9000, test | loss: 27.387, acc: 98.35%, ratio: 1967/2000
# ### Epoch 61 ###
# It: 9150, train | loss: 10.482, acc: 99.00%, ratio: 990/1000
# It: 9150, test | loss: 27.300, acc: 98.35%, ratio: 1967/2000
# ### Epoch 62 ###
# It: 9300, train | loss: 10.402, acc: 99.00%, ratio: 990/1000
# It: 9300, test | loss: 27.216, acc: 98.35%, ratio: 1967/2000
# ### Epoch 63 ###
# It: 9450, train | loss: 10.323, acc: 99.00%, ratio: 990/1000
# It: 9450, test | loss: 27.135, acc: 98.35%, ratio: 1967/2000
# ### Epoch 64 ###
# It: 9600, train | loss: 10.245, acc: 99.00%, ratio: 990/1000
# It: 9600, test | loss: 27.056, acc: 98.40%, ratio: 1968/2000
# ### Epoch 65 ###
# It: 9750, train | loss: 10.169, acc: 99.00%, ratio: 990/1000
# It: 9750, test | loss: 26.979, acc: 98.40%, ratio: 1968/2000
# ### Epoch 66 ###
# It: 9900, train | loss: 10.094, acc: 99.10%, ratio: 991/1000
# It: 9900, test | loss: 26.905, acc: 98.40%, ratio: 1968/2000
# ### Epoch 67 ###
# It: 10050, train | loss: 10.020, acc: 99.10%, ratio: 991/1000
# It: 10050, test | loss: 26.833, acc: 98.40%, ratio: 1968/2000
# ### Epoch 68 ###
# It: 10200, train | loss: 9.948, acc: 99.10%, ratio: 991/1000
# It: 10200, test | loss: 26.762, acc: 98.40%, ratio: 1968/2000
# ### Epoch 69 ###
# It: 10350, train | loss: 9.877, acc: 99.10%, ratio: 991/1000
# It: 10350, test | loss: 26.694, acc: 98.40%, ratio: 1968/2000
# ### Epoch 70 ###
# It: 10500, train | loss: 9.807, acc: 99.10%, ratio: 991/1000
# It: 10500, test | loss: 26.628, acc: 98.40%, ratio: 1968/2000
# ### Epoch 71 ###
# It: 10650, train | loss: 9.739, acc: 99.10%, ratio: 991/1000
# It: 10650, test | loss: 26.563, acc: 98.40%, ratio: 1968/2000
# ### Epoch 72 ###
# It: 10800, train | loss: 9.671, acc: 99.10%, ratio: 991/1000
# It: 10800, test | loss: 26.501, acc: 98.40%, ratio: 1968/2000
# ### Epoch 73 ###
# It: 10950, train | loss: 9.605, acc: 99.10%, ratio: 991/1000
# It: 10950, test | loss: 26.440, acc: 98.35%, ratio: 1967/2000
# ### Epoch 74 ###
# It: 11100, train | loss: 9.540, acc: 99.10%, ratio: 991/1000
# It: 11100, test | loss: 26.381, acc: 98.35%, ratio: 1967/2000
# ### Epoch 75 ###
# It: 11250, train | loss: 9.476, acc: 99.10%, ratio: 991/1000
# It: 11250, test | loss: 26.323, acc: 98.35%, ratio: 1967/2000
# ### Epoch 76 ###
# It: 11400, train | loss: 9.413, acc: 99.10%, ratio: 991/1000
# It: 11400, test | loss: 26.267, acc: 98.35%, ratio: 1967/2000
# ### Epoch 77 ###
# It: 11550, train | loss: 9.352, acc: 99.10%, ratio: 991/1000
# It: 11550, test | loss: 26.213, acc: 98.35%, ratio: 1967/2000
# ### Epoch 78 ###
# It: 11700, train | loss: 9.291, acc: 99.20%, ratio: 992/1000
# It: 11700, test | loss: 26.160, acc: 98.35%, ratio: 1967/2000
# ### Epoch 79 ###
# It: 11850, train | loss: 9.231, acc: 99.20%, ratio: 992/1000
# It: 11850, test | loss: 26.109, acc: 98.35%, ratio: 1967/2000
# ### Epoch 80 ###
# It: 12000, train | loss: 9.173, acc: 99.20%, ratio: 992/1000
# It: 12000, test | loss: 26.059, acc: 98.35%, ratio: 1967/2000
# ### Epoch 81 ###
# It: 12150, train | loss: 9.115, acc: 99.20%, ratio: 992/1000
# It: 12150, test | loss: 26.010, acc: 98.35%, ratio: 1967/2000
# ### Epoch 82 ###
# It: 12300, train | loss: 9.058, acc: 99.20%, ratio: 992/1000
# It: 12300, test | loss: 25.963, acc: 98.35%, ratio: 1967/2000
# ### Epoch 83 ###
# It: 12450, train | loss: 9.002, acc: 99.20%, ratio: 992/1000
# It: 12450, test | loss: 25.917, acc: 98.35%, ratio: 1967/2000
# ### Epoch 84 ###
# It: 12600, train | loss: 8.947, acc: 99.20%, ratio: 992/1000
# It: 12600, test | loss: 25.872, acc: 98.35%, ratio: 1967/2000
# ### Epoch 85 ###
# It: 12750, train | loss: 8.893, acc: 99.20%, ratio: 992/1000
# It: 12750, test | loss: 25.829, acc: 98.35%, ratio: 1967/2000
# ### Epoch 86 ###
# It: 12900, train | loss: 8.840, acc: 99.20%, ratio: 992/1000
# It: 12900, test | loss: 25.786, acc: 98.35%, ratio: 1967/2000
# ### Epoch 87 ###
# It: 13050, train | loss: 8.787, acc: 99.20%, ratio: 992/1000
# It: 13050, test | loss: 25.745, acc: 98.35%, ratio: 1967/2000
# ### Epoch 88 ###
# It: 13200, train | loss: 8.736, acc: 99.20%, ratio: 992/1000
# It: 13200, test | loss: 25.705, acc: 98.35%, ratio: 1967/2000
# ### Epoch 89 ###
# It: 13350, train | loss: 8.685, acc: 99.20%, ratio: 992/1000
# It: 13350, test | loss: 25.666, acc: 98.35%, ratio: 1967/2000
# ### Epoch 90 ###
# It: 13500, train | loss: 8.635, acc: 99.20%, ratio: 992/1000
# It: 13500, test | loss: 25.628, acc: 98.35%, ratio: 1967/2000
# ### Epoch 91 ###
# It: 13650, train | loss: 8.585, acc: 99.30%, ratio: 993/1000
# It: 13650, test | loss: 25.592, acc: 98.35%, ratio: 1967/2000
# ### Epoch 92 ###
# It: 13800, train | loss: 8.536, acc: 99.30%, ratio: 993/1000
# It: 13800, test | loss: 25.556, acc: 98.35%, ratio: 1967/2000
# ### Epoch 93 ###
# It: 13950, train | loss: 8.488, acc: 99.30%, ratio: 993/1000
# It: 13950, test | loss: 25.521, acc: 98.35%, ratio: 1967/2000
# ### Epoch 94 ###
# It: 14100, train | loss: 8.441, acc: 99.30%, ratio: 993/1000
# It: 14100, test | loss: 25.487, acc: 98.40%, ratio: 1968/2000
# ### Epoch 95 ###
# It: 14250, train | loss: 8.394, acc: 99.30%, ratio: 993/1000
# It: 14250, test | loss: 25.454, acc: 98.40%, ratio: 1968/2000
# ### Epoch 96 ###
# It: 14400, train | loss: 8.348, acc: 99.30%, ratio: 993/1000
# It: 14400, test | loss: 25.421, acc: 98.40%, ratio: 1968/2000
# ### Epoch 97 ###
# It: 14550, train | loss: 8.303, acc: 99.40%, ratio: 994/1000
# It: 14550, test | loss: 25.390, acc: 98.40%, ratio: 1968/2000
# ### Epoch 98 ###
# It: 14700, train | loss: 8.258, acc: 99.40%, ratio: 994/1000
# It: 14700, test | loss: 25.360, acc: 98.40%, ratio: 1968/2000
# ### Epoch 99 ###
# It: 14850, train | loss: 8.214, acc: 99.40%, ratio: 994/1000
# It: 14850, test | loss: 25.330, acc: 98.40%, ratio: 1968/2000
# ### Epoch 100 ###
# It: 15000, train | loss: 8.170, acc: 99.40%, ratio: 994/1000
# It: 15000, test | loss: 25.301, acc: 98.40%, ratio: 1968/2000
# ### Epoch 101 ###
# It: 15150, train | loss: 8.127, acc: 99.40%, ratio: 994/1000
# It: 15150, test | loss: 25.273, acc: 98.40%, ratio: 1968/2000
# ### Epoch 102 ###
# It: 15300, train | loss: 8.085, acc: 99.40%, ratio: 994/1000
# It: 15300, test | loss: 25.245, acc: 98.40%, ratio: 1968/2000
# ### Epoch 103 ###
# It: 15450, train | loss: 8.043, acc: 99.50%, ratio: 995/1000
# It: 15450, test | loss: 25.219, acc: 98.40%, ratio: 1968/2000
# ### Epoch 104 ###
# It: 15600, train | loss: 8.001, acc: 99.50%, ratio: 995/1000
# It: 15600, test | loss: 25.193, acc: 98.45%, ratio: 1969/2000
# ### Epoch 105 ###
# It: 15750, train | loss: 7.960, acc: 99.50%, ratio: 995/1000
# It: 15750, test | loss: 25.167, acc: 98.45%, ratio: 1969/2000
# ### Epoch 106 ###
# It: 15900, train | loss: 7.920, acc: 99.50%, ratio: 995/1000
# It: 15900, test | loss: 25.143, acc: 98.45%, ratio: 1969/2000
# ### Epoch 107 ###
# It: 16050, train | loss: 7.880, acc: 99.50%, ratio: 995/1000
# It: 16050, test | loss: 25.119, acc: 98.45%, ratio: 1969/2000
# ### Epoch 108 ###
# It: 16200, train | loss: 7.841, acc: 99.50%, ratio: 995/1000
# It: 16200, test | loss: 25.095, acc: 98.45%, ratio: 1969/2000
# ### Epoch 109 ###
# It: 16350, train | loss: 7.802, acc: 99.60%, ratio: 996/1000
# It: 16350, test | loss: 25.072, acc: 98.45%, ratio: 1969/2000
# ### Epoch 110 ###
# It: 16500, train | loss: 7.763, acc: 99.60%, ratio: 996/1000
# It: 16500, test | loss: 25.050, acc: 98.45%, ratio: 1969/2000
# ### Epoch 111 ###
# It: 16650, train | loss: 7.725, acc: 99.60%, ratio: 996/1000
# It: 16650, test | loss: 25.029, acc: 98.45%, ratio: 1969/2000
# ### Epoch 112 ###
# It: 16800, train | loss: 7.688, acc: 99.60%, ratio: 996/1000
# It: 16800, test | loss: 25.008, acc: 98.45%, ratio: 1969/2000
# ### Epoch 113 ###
# It: 16950, train | loss: 7.650, acc: 99.60%, ratio: 996/1000
# It: 16950, test | loss: 24.987, acc: 98.45%, ratio: 1969/2000
# ### Epoch 114 ###
# It: 17100, train | loss: 7.614, acc: 99.60%, ratio: 996/1000
# It: 17100, test | loss: 24.967, acc: 98.45%, ratio: 1969/2000
# ### Epoch 115 ###
# It: 17250, train | loss: 7.577, acc: 99.60%, ratio: 996/1000
# It: 17250, test | loss: 24.948, acc: 98.45%, ratio: 1969/2000
# ### Epoch 116 ###
# It: 17400, train | loss: 7.541, acc: 99.60%, ratio: 996/1000
# It: 17400, test | loss: 24.929, acc: 98.45%, ratio: 1969/2000
# ### Epoch 117 ###
# It: 17550, train | loss: 7.506, acc: 99.60%, ratio: 996/1000
# It: 17550, test | loss: 24.911, acc: 98.45%, ratio: 1969/2000
# ### Epoch 118 ###
# It: 17700, train | loss: 7.471, acc: 99.60%, ratio: 996/1000
# It: 17700, test | loss: 24.893, acc: 98.45%, ratio: 1969/2000
# ### Epoch 119 ###
# It: 17850, train | loss: 7.436, acc: 99.60%, ratio: 996/1000
# It: 17850, test | loss: 24.875, acc: 98.45%, ratio: 1969/2000
# ### Epoch 120 ###
# It: 18000, train | loss: 7.401, acc: 99.60%, ratio: 996/1000
# It: 18000, test | loss: 24.859, acc: 98.50%, ratio: 1970/2000
# ### Epoch 121 ###
# It: 18150, train | loss: 7.367, acc: 99.60%, ratio: 996/1000
# It: 18150, test | loss: 24.842, acc: 98.50%, ratio: 1970/2000
# ### Epoch 122 ###
# It: 18300, train | loss: 7.334, acc: 99.60%, ratio: 996/1000
# It: 18300, test | loss: 24.826, acc: 98.50%, ratio: 1970/2000
# ### Epoch 123 ###
# It: 18450, train | loss: 7.300, acc: 99.60%, ratio: 996/1000
# It: 18450, test | loss: 24.810, acc: 98.45%, ratio: 1969/2000
# ### Epoch 124 ###
# It: 18600, train | loss: 7.267, acc: 99.60%, ratio: 996/1000
# It: 18600, test | loss: 24.795, acc: 98.45%, ratio: 1969/2000
# ### Epoch 125 ###
# It: 18750, train | loss: 7.235, acc: 99.60%, ratio: 996/1000
# It: 18750, test | loss: 24.781, acc: 98.45%, ratio: 1969/2000
# ### Epoch 126 ###
# It: 18900, train | loss: 7.202, acc: 99.60%, ratio: 996/1000
# It: 18900, test | loss: 24.766, acc: 98.45%, ratio: 1969/2000
# ### Epoch 127 ###
# It: 19050, train | loss: 7.170, acc: 99.60%, ratio: 996/1000
# It: 19050, test | loss: 24.752, acc: 98.45%, ratio: 1969/2000
# ### Epoch 128 ###
# It: 19200, train | loss: 7.138, acc: 99.60%, ratio: 996/1000
# It: 19200, test | loss: 24.739, acc: 98.45%, ratio: 1969/2000
# ### Epoch 129 ###
# It: 19350, train | loss: 7.107, acc: 99.60%, ratio: 996/1000
# It: 19350, test | loss: 24.726, acc: 98.45%, ratio: 1969/2000
# ### Epoch 130 ###
# It: 19500, train | loss: 7.076, acc: 99.60%, ratio: 996/1000
# It: 19500, test | loss: 24.713, acc: 98.45%, ratio: 1969/2000
# ### Epoch 131 ###
# It: 19650, train | loss: 7.045, acc: 99.60%, ratio: 996/1000
# It: 19650, test | loss: 24.700, acc: 98.45%, ratio: 1969/2000
# ### Epoch 132 ###
# It: 19800, train | loss: 7.015, acc: 99.60%, ratio: 996/1000
# It: 19800, test | loss: 24.688, acc: 98.40%, ratio: 1968/2000
# ### Epoch 133 ###
# It: 19950, train | loss: 6.984, acc: 99.60%, ratio: 996/1000
# It: 19950, test | loss: 24.677, acc: 98.40%, ratio: 1968/2000
# ### Epoch 134 ###
# It: 20100, train | loss: 6.954, acc: 99.60%, ratio: 996/1000
# It: 20100, test | loss: 24.665, acc: 98.40%, ratio: 1968/2000
# ### Epoch 135 ###
# It: 20250, train | loss: 6.925, acc: 99.60%, ratio: 996/1000
# It: 20250, test | loss: 24.654, acc: 98.40%, ratio: 1968/2000
# ### Epoch 136 ###
# It: 20400, train | loss: 6.895, acc: 99.60%, ratio: 996/1000
# It: 20400, test | loss: 24.644, acc: 98.40%, ratio: 1968/2000
# ### Epoch 137 ###
# It: 20550, train | loss: 6.866, acc: 99.60%, ratio: 996/1000
# It: 20550, test | loss: 24.633, acc: 98.40%, ratio: 1968/2000
# ### Epoch 138 ###
# It: 20700, train | loss: 6.837, acc: 99.60%, ratio: 996/1000
# It: 20700, test | loss: 24.623, acc: 98.40%, ratio: 1968/2000
# ### Epoch 139 ###
# It: 20850, train | loss: 6.809, acc: 99.60%, ratio: 996/1000
# It: 20850, test | loss: 24.614, acc: 98.40%, ratio: 1968/2000
# ### Epoch 140 ###
# It: 21000, train | loss: 6.781, acc: 99.60%, ratio: 996/1000
# It: 21000, test | loss: 24.604, acc: 98.40%, ratio: 1968/2000
# ### Epoch 141 ###
# It: 21150, train | loss: 6.752, acc: 99.60%, ratio: 996/1000
# It: 21150, test | loss: 24.595, acc: 98.40%, ratio: 1968/2000
# ### Epoch 142 ###
# It: 21300, train | loss: 6.725, acc: 99.60%, ratio: 996/1000
# It: 21300, test | loss: 24.587, acc: 98.40%, ratio: 1968/2000
# ### Epoch 143 ###
# It: 21450, train | loss: 6.697, acc: 99.60%, ratio: 996/1000
# It: 21450, test | loss: 24.578, acc: 98.40%, ratio: 1968/2000
# ### Epoch 144 ###
# It: 21600, train | loss: 6.670, acc: 99.60%, ratio: 996/1000
# It: 21600, test | loss: 24.570, acc: 98.40%, ratio: 1968/2000
# ### Epoch 145 ###
# It: 21750, train | loss: 6.642, acc: 99.60%, ratio: 996/1000
# It: 21750, test | loss: 24.562, acc: 98.40%, ratio: 1968/2000
# ### Epoch 146 ###
# It: 21900, train | loss: 6.616, acc: 99.70%, ratio: 997/1000
# It: 21900, test | loss: 24.554, acc: 98.40%, ratio: 1968/2000
# ### Epoch 147 ###
# It: 22050, train | loss: 6.589, acc: 99.70%, ratio: 997/1000
# It: 22050, test | loss: 24.547, acc: 98.40%, ratio: 1968/2000
# ### Epoch 148 ###
# It: 22200, train | loss: 6.562, acc: 99.70%, ratio: 997/1000
# It: 22200, test | loss: 24.540, acc: 98.40%, ratio: 1968/2000
# ### Epoch 149 ###
# It: 22350, train | loss: 6.536, acc: 99.70%, ratio: 997/1000
# It: 22350, test | loss: 24.533, acc: 98.40%, ratio: 1968/2000

# %%
# np.save(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{"training"}_{"loss_history"}.npy', train_loss_history)
# np.save(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{"training"}_{"accuracy_history"}.npy', train_accuracy_history)
# np.save(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{"test"}_{"loss_history"}.npy', test_loss_history)
# np.save(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{"test"}_{"accuracy_history"}.npy', test_accuracy_history)
# np.save(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{""}_{"times"}.npy', times)

# %%
# train_loss_history = np.load(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{"training"}_{"loss_history"}.npy')
# train_accuracy_history = np.load(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{"training"}_{"accuracy_history"}.npy')
# test_loss_history = np.load(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{"test"}_{"loss_history"}.npy')
# test_accuracy_history = np.load(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{"test"}_{"accuracy_history"}.npy')
# times = np.load(f'./experiments/CNN_FashionMNIST_NonConvex_optim_{"Adam"}_lr_{1e-4}_epochs_{400}_{""}_{"times"}.npy')

convex_time = 65.877
convex_train_loss = 0.0008672259147097226
convex_train_accuracy = 1.0
convex_test_loss = 61.3037
convex_test_accuracy = 0.954

max_timerange = int(max(max(times), convex_time))
timerange = list(range(max_timerange))

plt.rcParams.update({'font.size': 40})
plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
plt.rc('legend', fontsize=20)
plt.xlabel('Time (sec)')

plt.semilogy(times, train_loss_history, linewidth=3, label='Backpropagation (Adam)')
plt.ylabel(r'Training loss')
plt.plot(timerange,[convex_train_loss]*max_timerange, "--", color='r')
plt.plot(convex_time, convex_train_loss, 'rx', linewidth=3, markersize=12, markeredgewidth=3, label="Convex SDP (optimal)")
plt.legend()
# plt.savefig(f'./plots/CNN_NoPooling_FashionMNIST_{"training"}_{"loss"}')
plt.show()

plt.plot(times, train_accuracy_history, linewidth=3, label='Backpropagation (Adam)')
plt.ylabel('Accuracy')
plt.plot(timerange,[convex_train_accuracy]*max_timerange, "--", color='r')
plt.plot(convex_time, convex_train_accuracy, 'rx', linewidth=3, markersize=12, markeredgewidth=3, label="Convex SDP (optimal)")
plt.legend()
# plt.savefig(f'./plots/CNN_NoPooling_FashionMNIST_{"training"}_{"accuracy"}')
plt.show()


plt.semilogy(times, test_loss_history, linewidth=3, label='Backpropagation (Adam)')
plt.ylabel(r'Test loss')
plt.plot(timerange,[convex_test_loss]*max_timerange, "--", color='r')
plt.plot(convex_time, convex_test_loss, 'rx', linewidth=3, markersize=12, markeredgewidth=3, label="Convex SDP (optimal)")
plt.legend()
# plt.savefig(f'./plots/CNN_NoPooling_FashionMNIST_{"test"}_{"loss"}')
plt.show()

plt.plot(times, test_accuracy_history, linewidth=3, label='Backpropagation (Adam)')
plt.ylabel('Accuracy')
plt.plot(timerange,[convex_test_accuracy]*max_timerange, "--", color='r')
plt.plot(convex_time, convex_test_accuracy, 'rx', linewidth=3, markersize=12, markeredgewidth=3, label="Convex SDP (optimal)")
plt.legend()
# plt.savefig(f'./plots/CNN_NoPooling_FashionMNIST_{"test"}_{"accuracy"}')
plt.show()
